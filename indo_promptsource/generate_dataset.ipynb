# %%
from tqdm import tqdm
import pandas as pd
from promptsource.templates import DatasetTemplates
# !pip install nusacrowd
from nusacrowd import NusantaraConfigHelper
import logging
import argparse

# parser = argparse.ArgumentParser()
# parser.add_argument('--dataset-name', help='Dataset name')
# parser.add_argument('--subset-name', help='Subset name')
# args = parser.parse_args()

# Set up the logger
logging.basicConfig(
    level=logging.DEBUG,  # Set the desired logging level (DEBUG, INFO, WARNING, ERROR, CRITICAL)
    format='%(asctime)s [%(levelname)s]: %(message)s',  # Customize the log message format
    datefmt='%Y-%m-%d %H:%M:%S'  # Customize the date/time format
)

# Create a file handler to write logs into a file
file_handler = logging.FileHandler('app.log')
file_handler.setLevel(logging.DEBUG)  # Set the log level for the file handler

# Create a formatter for the file handler (customize the log format for the file)
file_formatter = logging.Formatter('%(asctime)s [%(levelname)s]: %(message)s', datefmt='%Y-%m-%d %H:%M:%S')
file_handler.setFormatter(file_formatter)

logger = logging.getLogger("IndoP3 Dataset Generation")
logger.addHandler(file_handler)

conhelps = NusantaraConfigHelper()

all_data = []
checkpoint_save_path = "generated_dataset"

dataset_name = "indo_law" #args.dataset_name
subset_name = "nusa" #args.subset_name
logger.info(f"Input dataset_name: {dataset_name}")
logger.info(f"Input subset_name: {subset_name}")

# Load dataset
nusa_metadata = conhelps.filtered(lambda x: dataset_name in x.dataset_name and subset_name in x.config.name)[0]
dataset_name = nusa_metadata.dataset_name
subset_name = nusa_metadata.config.name
dset = nusa_metadata.load_dataset()
logger.info("============================================")
logger.info(f"## DATASET INFO ##")
logger.info(f"Real dataset_name: {dataset_name}")
logger.info(f"Real subset_name: {subset_name}")
logger.info(f"dset.shape: {dset.shape}")
example = dset["train"][0]
logger.info(f"Example dataset: {example}")
logger.info("============================================")


# Load prompt
prompt = DatasetTemplates(dataset_name, subset_name=subset_name)

# Iterate to each prompt templates
for prompt_id in tqdm(prompt.templates):
    template_name = prompt.templates[prompt_id].name

    for dataset_key in dset.keys():
        for example in dset[dataset_key]:
            data_details = {
                "dataset_name": dataset_name,
                "subset_name": subset_name,
                "prompt_id": prompt_id,
                "template_name": template_name,
                "dataset_key": dataset_key,
            }
            input = None
            output = None

            try:
                render = prompt[template_name].apply(example)
                if len(render) != 2:
                    if len(render) == 1:
                        input = render[0]

                    logger.info(f"Output not available for {data_details}.")
                    break
                else:
                    input = render[0]
                    output = render[1]
            except Exception as e:
                logger.error(f"Exception occurred on {data_details}. Please rectify: {e}")
                break
            
            data_details["input"] = input
            data_details["output"] = output

            all_data.append(
                data_details
            )
    
df_ = pd.DataFrame(all_data)
df_.to_csv(f"{checkpoint_save_path}/{dataset_name}-{subset_name}.csv")
# Out:
# Requirement already satisfied: nusacrowd in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (0.1.0)
# Requirement already satisfied: loguru>=0.5.3 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nusacrowd) (0.7.0)
# Requirement already satisfied: bioc>=1.3.7 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nusacrowd) (2.1)
# Requirement already satisfied: pandas>=1.3.3 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nusacrowd) (2.0.3)
# Requirement already satisfied: numpy>=1.20 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nusacrowd) (1.24.4)
# Requirement already satisfied: datasets>=2.2.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nusacrowd) (2.14.4)
# Requirement already satisfied: black~=22.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nusacrowd) (22.12.0)
# Requirement already satisfied: flake8>=3.8.3 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nusacrowd) (6.1.0)
# Requirement already satisfied: isort>=5.0.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nusacrowd) (5.12.0)
# Requirement already satisfied: aiohttp>=3.8.1 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nusacrowd) (3.8.5)
# Requirement already satisfied: pre-commit>=2.19.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nusacrowd) (3.3.3)
# Requirement already satisfied: jsonlines>=3.1.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nusacrowd) (3.1.0)
# Requirement already satisfied: torchaudio>=0.11 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nusacrowd) (2.0.2)
# Requirement already satisfied: soundfile in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nusacrowd) (0.12.1)
# Requirement already satisfied: librosa in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nusacrowd) (0.10.1)
# Requirement already satisfied: nltk in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nusacrowd) (3.8.1)
# Requirement already satisfied: zstandard in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nusacrowd) (0.21.0)
# Requirement already satisfied: ffmpeg in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nusacrowd) (1.4)
# Requirement already satisfied: conllu in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nusacrowd) (4.5.3)
# Requirement already satisfied: openpyxl in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nusacrowd) (3.1.2)
# Requirement already satisfied: translate-toolkit>=3.7.3 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nusacrowd) (3.10.0)
# Requirement already satisfied: typing-extensions in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nusacrowd) (4.7.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from aiohttp>=3.8.1->nusacrowd) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from aiohttp>=3.8.1->nusacrowd) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from aiohttp>=3.8.1->nusacrowd) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from aiohttp>=3.8.1->nusacrowd) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from aiohttp>=3.8.1->nusacrowd) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from aiohttp>=3.8.1->nusacrowd) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from aiohttp>=3.8.1->nusacrowd) (1.3.1)
# Requirement already satisfied: lxml>=4.6.3 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from bioc>=1.3.7->nusacrowd) (4.9.3)
# Requirement already satisfied: intervaltree in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from bioc>=1.3.7->nusacrowd) (3.1.0)
# Requirement already satisfied: tqdm in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from bioc>=1.3.7->nusacrowd) (4.65.0)
# Requirement already satisfied: docopt in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from bioc>=1.3.7->nusacrowd) (0.6.2)
# Requirement already satisfied: click>=8.0.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from black~=22.0->nusacrowd) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from black~=22.0->nusacrowd) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from black~=22.0->nusacrowd) (0.11.2)
# Requirement already satisfied: platformdirs>=2 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from black~=22.0->nusacrowd) (3.10.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from datasets>=2.2.0->nusacrowd) (12.0.1)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from datasets>=2.2.0->nusacrowd) (0.3.7)
# Requirement already satisfied: requests>=2.19.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from datasets>=2.2.0->nusacrowd) (2.31.0)
# Requirement already satisfied: xxhash in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from datasets>=2.2.0->nusacrowd) (3.3.0)
# Requirement already satisfied: multiprocess in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from datasets>=2.2.0->nusacrowd) (0.70.15)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from datasets>=2.2.0->nusacrowd) (2023.6.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from datasets>=2.2.0->nusacrowd) (0.16.4)
# Requirement already satisfied: packaging in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from datasets>=2.2.0->nusacrowd) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from datasets>=2.2.0->nusacrowd) (6.0)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from flake8>=3.8.3->nusacrowd) (0.7.0)
# Requirement already satisfied: pycodestyle<2.12.0,>=2.11.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from flake8>=3.8.3->nusacrowd) (2.11.0)
# Requirement already satisfied: pyflakes<3.2.0,>=3.1.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from flake8>=3.8.3->nusacrowd) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from pandas>=1.3.3->nusacrowd) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from pandas>=1.3.3->nusacrowd) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from pandas>=1.3.3->nusacrowd) (2023.3)
# Requirement already satisfied: cfgv>=2.0.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from pre-commit>=2.19.0->nusacrowd) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from pre-commit>=2.19.0->nusacrowd) (2.5.26)
# Requirement already satisfied: nodeenv>=0.11.1 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from pre-commit>=2.19.0->nusacrowd) (1.8.0)
# Requirement already satisfied: virtualenv>=20.10.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from pre-commit>=2.19.0->nusacrowd) (20.24.3)
# Requirement already satisfied: torch==2.0.1 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from torchaudio>=0.11->nusacrowd) (2.0.1)
# Requirement already satisfied: filelock in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from torch==2.0.1->torchaudio>=0.11->nusacrowd) (3.12.2)
# Requirement already satisfied: sympy in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from torch==2.0.1->torchaudio>=0.11->nusacrowd) (1.12)
# Requirement already satisfied: networkx in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from torch==2.0.1->torchaudio>=0.11->nusacrowd) (3.1)
# Requirement already satisfied: jinja2 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from torch==2.0.1->torchaudio>=0.11->nusacrowd) (3.1.2)
# Requirement already satisfied: audioread>=2.1.9 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from librosa->nusacrowd) (3.0.0)
# Requirement already satisfied: scipy>=1.2.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from librosa->nusacrowd) (1.11.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from librosa->nusacrowd) (1.3.0)
# Requirement already satisfied: joblib>=0.14 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from librosa->nusacrowd) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from librosa->nusacrowd) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from librosa->nusacrowd) (0.57.1)
# Requirement already satisfied: pooch>=1.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from librosa->nusacrowd) (1.7.0)
# Requirement already satisfied: soxr>=0.3.2 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from librosa->nusacrowd) (0.3.6)
# Requirement already satisfied: lazy-loader>=0.1 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from librosa->nusacrowd) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from librosa->nusacrowd) (1.0.5)
# Requirement already satisfied: cffi>=1.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from soundfile->nusacrowd) (1.15.1)
# Requirement already satisfied: regex>=2021.8.3 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nltk->nusacrowd) (2023.8.8)
# Requirement already satisfied: et-xmlfile in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from openpyxl->nusacrowd) (1.1.0)
# Requirement already satisfied: pycparser in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from cffi>=1.0->soundfile->nusacrowd) (2.21)
# Requirement already satisfied: setuptools in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from nodeenv>=0.11.1->pre-commit>=2.19.0->nusacrowd) (68.0.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from numba>=0.51.0->librosa->nusacrowd) (0.40.1)
# Requirement already satisfied: six>=1.5 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.3->nusacrowd) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from requests>=2.19.0->datasets>=2.2.0->nusacrowd) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from requests>=2.19.0->datasets>=2.2.0->nusacrowd) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from requests>=2.19.0->datasets>=2.2.0->nusacrowd) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from scikit-learn>=0.20.0->librosa->nusacrowd) (3.2.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from virtualenv>=20.10.0->pre-commit>=2.19.0->nusacrowd) (0.3.7)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from intervaltree->bioc>=1.3.7->nusacrowd) (2.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from jinja2->torch==2.0.1->torchaudio>=0.11->nusacrowd) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/ihza.mahendra/anaconda3/envs/promptsource/lib/python3.11/site-packages (from sympy->torch==2.0.1->torchaudio>=0.11->nusacrowd) (1.3.0)
# 2023-08-18 08:42:13 [INFO]: Input dataset_name: indo_law
# 2023-08-18 08:42:13 [INFO]: Input subset_name: nusa
# 2023-08-18 08:42:13 [DEBUG]: open file: /Users/ihza.mahendra/.cache/huggingface/datasets/indo_law/indo_law_nusantara_text/1.0.0/e901cc1faecaf0f01dd1c6647597be69bb401d1036603cc1b778e8e440944ac6/dataset_info.json
# 2023-08-18 08:42:13 [DEBUG]: open file: /Users/ihza.mahendra/.cache/huggingface/datasets/indo_law/indo_law_nusantara_text/1.0.0/e901cc1faecaf0f01dd1c6647597be69bb401d1036603cc1b778e8e440944ac6/dataset_info.json
# 2023-08-18 08:42:13 [INFO]: ============================================
# 2023-08-18 08:42:13 [INFO]: ## DATASET INFO ##
# 2023-08-18 08:42:13 [INFO]: Real dataset_name: indo_law
# 2023-08-18 08:42:13 [INFO]: Real subset_name: indo_law_nusantara_text
# 2023-08-18 08:42:13 [INFO]: dset.shape: {'train': (22630, 3)}
# 2023-08-18 08:42:13 [INFO]: Example dataset: {'id': '9f73f714b56ea3f527b70db6e50c29dc', 'text': '{"kepala_putusan": "\\nputusan\\nnomor 684 pid sus 2019 pn blb\\ndemi keadilan berdasarkan ketuhanan yang maha esa\\npengadilan negeri bale bandung kelas i a yang mengadili perkara pidana dengan acara pemeriksaan biasa dalam tingkat pertama menjatuhkan putusan sebagai berikut dalam perkara terdakwa\\n", "identitas": "\\nnama lengkap muhajir abdul yakin alias supir alias takur bin totong hana putih indonesia tempat lahir umur tanggal lahir jenis kelamin kebangsaan tempat tinggal bandung\\n20 tahun 02 agustus 1999 laki laki kampung cinangka rt 001 rw 006 desa rajamandala kulon kecamatan cipatat kabupaten bandung barat islam agama pekerjaan tunakarya terdakwa dilakukan penangkapan oleh penyidik tanggal 25 juli 2019\\n", "riwayat_penahanan": "\\ntelah ditahan dengan surat perintah penetapan penahanan\\n1 penahanan oleh penyidik sejak tanggal 26 juli 2019 sampai dengan tanggal 14 agustus 2019\\n2 perpanjangan oleh penuntut umum sejak tanggal 15 agustus 2019 sampai dengan tanggal 23 september 2019\\n3 penahanan oleh penuntut umum sejak tanggal 10 september 2019 sampai dengan tanggal 29 september 2019\\n4 penahanan oleh hakim peng